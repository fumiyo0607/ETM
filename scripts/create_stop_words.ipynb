# %%
import pandas as pd
import random

# %%
all_stop_words = pd.read_csv('./stops.txt', header=None, )
all_stop_words.head()
# Out:
#            0
# 0          a
# 1       able
# 2      about
# 3      above
# 4  according

# %%
all_stop_words.tail()
# Out:
#               0
# 519       yours
# 520    yourself
# 521  yourselves
# 522           z
# 523        zero

# %%
stop_words_file = 'stops.txt'
with open(stop_words_file, 'r') as f:
    stops = f.read().split('\n')
    
stops
# Out:
# ['a',
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  'came',
#  'can',
#  'cannot',
# ...

# %%
random_stops = random.sample(stops, 100)

# %%
print(random_stops)
print(len(random_stops))
# Out:
# ['already', 'quite', 'known', 'somewhat', 'associated', 'awfully', 'well', 'among', 'ok', 'whereby', 'must', 'former', 'sub', 'specify', 'theirs', 'than', 'outside', 'him', 'nobody', 'z', 'contain', 'also', 'per', 'much', 'everyone', 'anyway', 'he', 'through', 'looks', 'somebody', 'gotten', 'r', 'am', 'behind', 'mean', 'says', 'even', 'just', 'probably', 'contains', 'another', 'mostly', 'myself', 'for', 'wants', 'so', 'needs', 'w', 'new', 'too', 'consequently', 'anyhow', 'gives', 'wish', 'particularly', 'anyways', 'ask', 'c', 'normally', 'get', 'really', 'saw', 'having', 'sometime', 'would', 'indeed', 'b', 'himself', 'appreciate', 'corresponding', 'under', 'except', 'some', 'before', 'clearly', 'e', 'these', 'down', 'certainly', 'first', 'his', 'best', 'against', 'become', 'reasonably', 'formerly', 'our', 'would', 'perhaps', 'please', 'those', 'rd', 'keeps', 'plus', 'upon', 'relatively', 'namely', 'go', 'whether', 'whoever']
# 100

# %%
import pickle

import pickle
with open('./max_df=0.7-min_df=10-stop_words_num=100/vocab.pkl', 'rb') as data:
    vocab = pickle.load(data)

# %%
len(vocab)
# Out:
# 19007

# %%
topic_list = []
for k in range(5):
    topic_list += [k] * 2

# %%
topic_list
# Out:
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 4]
